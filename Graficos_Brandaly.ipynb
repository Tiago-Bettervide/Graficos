# %%
import matplotlib.pyplot as plt

Wavelengh = [0.48, 0.56, 0.65, 0.86, 1.61, 2.2]
Urban_built_up = [0.06, 0.085, 0.117, 0.193, 0.28, 0.235]
Urban_shadow = [0.023, 0.03, 0.03, 0.041, 0.061, 0.059]
Urban_vegetation = [0.018, 0.035, 0.023, 0.302, 0.1, 0.038]
Global_substrate = [0.178, 0.337, 0.458, 0.559, 0.683, 0.645]
Global_dark = [0.019, 0.01, 0.005, 0.007, 0.003, 0.002]
Global_vegetation = [0.03, 0.06, 0.031, 0.669, 0.24, 0.096]



plt.plot(Wavelengh, Urban_built_up, label="Urban built-up")
plt.plot(Wavelengh, Urban_shadow, label="Urban shadow")
plt.plot(Wavelengh, Urban_vegetation, label="Urban vegetation")
plt.plot(Wavelengh, Global_substrate, label="Global substrate")
plt.plot(Wavelengh, Global_dark, label="Global dark")
plt.plot(Wavelengh, Global_vegetation, label="global vegetation")

plt.xlabel("Wavelengh")
plt.ylabel('Reflectance')
plt.title("Exemplo")

plt.legend()

plt.show()

# %%
labels = ['Gelo', 'Neve', 'Rocha', 'Água', 'Crosta', 'vegetação']
sections = [47410.00, 89383.00, 114519.00, 1.10, 41321.00, 9876.00 ]
colors = ['c', 'b', 'y', 'b', 'r', 'g']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode=(0, 0.1, 0, 0, 0, 0),
        autopct='%1.2f%%')

plt.axis('equal')
plt.title('Junho')
plt.show()

# %%
labels = ['Gelo', 'Neve', 'Rocha', 'Água', 'Crosta', 'vegetação']
sections = [38191.00, 52008.00, 173168.00, 0.00, 32256.00, 6888.00 ]
colors = ['c', 'b', 'y', 'b', 'r', 'g']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode=(0, 0.2, 0, 0, 0, 0),
        autopct='%1.2f%%')

plt.axis('equal')
plt.title('Outubro')
plt.show()

# %%
import matplotlib.pyplot as plt

X =['jan-22','fev-22','mar-22','abr-22','mai-22','jun-22','jul-22','ago-22','set-22','out-22','nov-22','dez-22','jan-23','fev-23','mar-23','abr-23','mai-23','jun-23','jul-23','ago-23','set-23','out-23','nov-23', 'dez-23']
P0 =[-2.7,-2.1,-2.6, -4.6,-8.3,-12.2,-10.6,-10.6,-6.9,-6.3,-5.3,-3.5,-2.5,-1.9,-2.7,-5.1,-8.7,-11.7,-10.4,-10.4,-6.6,-5.3,-4.5,-1.7]
P1 =[-2, -1.5, -1.9, -3.9, -7.7, -11.5, -9.8, -10, -6.2, -5.5, -4.5, -2.9, -1.8, -1.3, -2, -4.4, -8.1, -11.1, -9.7, -9.7, -5.9, -4.5, -3.7, -1]
P2 =[-1.7, -1.1, -1.5, -3.7, -7.3, -11.1, -9.4, -9.5, -5.8, -5, -4.2, -2.4, -1.5, -1, -1.6, -4.1, -7.7, -10.7, -9.4, -9.2, -5.5, -4, -3.4, -0.5]
P15 =[-2, -1.4, -1.9, -3.9, -7.6, -11.5, -9.8, -10, -6.1, -5.4, -4.3, -2.8, -1.6, -1.4, -2, -4.4, -8.4, -11.1, -9.7, -9.8, -6, -4.5, -3.8, -1]

plt.plot(X, P0, label="PONTO 0")
plt.plot(X, P1, label="PONTO 1")
plt.plot(X, P2, label="PONTO 2")
plt.plot(X, P3, label="PONTO 3")
plt.plot(X, P4, label="PONTO 4")
plt.plot(X, P5, label="PONTO 5")
plt.plot(X, P6, label="PONTO 6")
plt.plot(X, P7, label="PONTO 7")
plt.plot(X, P8, label="PONTO 8")
plt.plot(X, P9, label="PONTO 9")
plt.plot(X, P10, label="PONTO 10")
plt.plot(X, P11, label="PONTO 11")
plt.plot(X, P12, label="PONTO 12")
plt.plot(X, P13, label="PONTO 13")
plt.plot(X, P14, label="PONTO 14")
plt.plot(X, P15, label="PONTO 15")


plt.title("Dados de Vários Pontos ao Longo do Tempo")
plt.xlabel("Meses")
plt.ylabel("Valores")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)


plt.tight_layout()
plt.show()

# %%
Mês_Ano = ['mar-22', 'abr-22', 'mai-22', 'jun-22', 'jul-22', 'ago-22', 'set-22', 'out-22', 'nov-22', 'jan-23', 'fev-23', 'abr-23', 'mai-23', 'jun-23', 'jul-23', 'ago-23', 'set-23', 'out-23', 'dez-23']
Gelo = [57.436, 51.675, 49.342, 48.507, 45.057, 43.681, 42.366, 41.648, 41.547, 42.141, 43.921, 47.527, 53.554, 46.312, 42.796, 42.025, 44.498, 38.191, 36.543]
Neve = [70.855, 47.288, 50.364, 42.366, 91.694, 50.238, 86.276, 47.947, 51.199, 73.988, 88.829, 92.973, 64.066, 89.383, 77.347, 76.881, 49.162, 52.008, 51.297]
Rocha = [117.553, 146.068, 158.508, 171.504, 123.840, 170.530, 141.461, 179.276, 164.482, 142.153, 139.828, 112.156, 125.081, 114.519, 142.958, 143.889, 172.243, 173.168, 154.783]
Água = [0, 0.83, 0.89, 0, 1.112, 0.96, 0, 0, 0, 0, 0.85, 0, 0, 1.10, 0, 0, 0, 0, 0]
Crosta = [42.077, 42.677, 34.218, 32.458, 33.825, 29.614, 24.490, 25.625, 31.248, 37.111, 17.751, 38.468, 45.107, 41.321, 31.787, 31.801, 28.378, 32.256, 46.982]
Vegetação_água = [14.590, 13.968, 9.188, 7.676, 6.982, 7.486, 7.917, 8.016, 14.035, 7.117, 11.325, 11.386, 14.703, 9.876, 7.624, 7.914, 8.231, 6.888, 12.906]

plt.plot(Mês_Ano, Gelo, label="Gelo")
plt.plot(Mês_Ano, Neve, label="Neve")
plt.plot(Mês_Ano, Rocha, label="Rocha")
plt.plot(Mês_Ano, Água, label="Água")
plt.plot(Mês_Ano, Crosta, label="Crosta")
plt.plot(Mês_Ano, Vegetação_água, label="Vegetação+água")

plt.title("Dados de Vários Pontos ao Longo do Tempo")
plt.xlabel("Meses")
plt.ylabel("Área")
plt.xticks(rotation=45)
#plt.legend()
plt.grid(True)


plt.tight_layout()
plt.show()
