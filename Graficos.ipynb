# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = ['Gelo', 'Neve', 'Rocha', 'Crostas biológicas', 'Bofedales']
y1 = [47410.00, 89383.00, 114519.00, 41321.00, 9876.00]
y2 = [38191.00, 52008.00, 173168.00, 32256.00, 6888.00]

total_y1 = sum(y1)
total_y2 = sum(y2)

y1_percent = [(valor / total_y1) * 100 for valor in y1]
y2_percent = [(valor / total_y2) * 100 for valor in y2]

plt.figure(figsize=(12, 6))


bar_width = 0.3
space = 0.1
index = np.arange(len(x1))


plt.bar(index, y1, bar_width, label="Junho", color='#0072B8')
plt.bar(index + bar_width + space, y2, bar_width, label="Outubro", color='#990000')

plt.ylabel('Área (km²)')

for i in range(len(y1)):

    if i == 2:
        plt.text(i, y1[i] + 2500, f'{y1_percent[i]:.1f}%', ha='center', va='bottom')
        plt.text(i + bar_width + space, y2[i] + 2500, f'{y2_percent[i]:.1f}%', ha='center', va='bottom')
    else:
        plt.text(i, y1[i] + 5000, f'{y1_percent[i]:.1f}%', ha='center', va='bottom')
        plt.text(i + bar_width + space, y2[i] + 5000, f'{y2_percent[i]:.1f}%', ha='center', va='bottom')
plt.xticks(index + (bar_width + space) / 2, x1)

plt.grid(axis='y', linestyle='-', alpha=0.7)

plt.tight_layout()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=4)
plt.savefig('grafico_area_km2.png', format='png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [f'p{i}' for i in range(16)]

jun_23_min = [-11.7, -11.1, -10.7, -10.4, -11.2, -12.4, -11.2, -10.5,
              -9.8, -10.5, -12.1, -12.8, -11.5, -10.7, -11.7, -11.1]

out_23_min = [-5.3, -4.5, -4.0, -3.5, -4.5, -6.2, -4.8, -3.9,
               -2.9, -3.7, -5.7, -6.6, -5.0, -4.1, -5.4, -4.5]

jun_23_max = [10.5, 11.3, 11.8, 12.3, 11.3, 9.7, 11.2, 12.0,
               13.0, 12.2, 10.1, 9.3, 10.9, 12.0, 10.7, 11.5]

out_23_max = [13.3, 14.0, 14.4, 15.1, 14.1, 12.4, 13.8, 14.5,
               15.9, 15.0, 13.1, 12.1, 13.6, 14.8, 13.5, 14.2]

plt.figure(figsize=(14, 7))

plt.plot(x, jun_23_min, marker='o', label='Jun/23 Mín.', color='#0072B8', linestyle='--')  # Vermelho, linha pontilhada
plt.plot(x, out_23_min, marker='s', label='Out/23 Mín.', color='#D7191C', linestyle='--')   # Azul, linha pontilhada
plt.plot(x, jun_23_max, marker='^', label='Jun/23 Máx.', color='#0072B8', linestyle='-')   # Verde, linha sólida
plt.plot(x, out_23_max, marker='x', label='Out/23 Máx.', color='#D7191C', linestyle='-')   # Amarelo, linha sólida

plt.ylabel('Temperatura (°C)')
plt.ylim(-15, 20)

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=4)
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.tight_layout()

plt.savefig('grafico_temperatura.png', format='png', dpi=300, bbox_inches='tight')
plt.show()
